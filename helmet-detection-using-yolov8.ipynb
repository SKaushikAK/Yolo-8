# %%
# Install Ultralytics
# !pip install -q ultralytics

# dataset https://www.kaggle.com/datasets/andrewmvd/helmet-detection
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.6 MB/s eta 0:00:00a 0:00:01

# %%
# Import necessary libraries
import os
import shutil
import yaml
import glob
from xml.dom import minidom
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# ==========================
# 📌 Step 1: YAML File Setup
# ==========================
yaml_path = "/kaggle/working/dataset.yaml"

data = {
    "train": "/kaggle/working/images",
    "val": "/kaggle/working/images",
    "test": "/kaggle/working/images",
    "nc": 2,
    "names": ["Without Helmet", "With Helmet"]
}

# Write dataset.yaml
with open(yaml_path, "w") as f:
    yaml.dump(data, f, default_flow_style=False)

print("✅ dataset.yaml created successfully!")
# Out:
# ✅ dataset.yaml created successfully!

# %%
# ==========================
# 📌 Step 2: Prepare Directory Structure
# ==========================
label_dir = "/kaggle/working/labels"

# Remove old labels folder and create a new one
if os.path.exists(label_dir):
    shutil.rmtree(label_dir)
os.makedirs(label_dir, exist_ok=True)
print(f"✅ Created clean label directory: {label_dir}")

# Copy images from dataset
# !cp -r /kaggle/input/helmet-detection/images/ /kaggle/working/
# Out:
# ✅ Created clean label directory: /kaggle/working/labels

# %%
# ==========================
# 📌 Step 3: Convert XML Annotations to YOLO Format
# ==========================
lut = {"Without Helmet": 0, "With Helmet": 1}  # Class lookup table

def get_text(tag, parent):
    """Helper function to extract text from an XML tag."""
    return parent.getElementsByTagName(tag)[0].firstChild.data

def convert_coordinates(size, box):
    """Convert Pascal VOC bounding box format to YOLO format."""
    dw, dh = 1.0 / size[0], 1.0 / size[1]
    x = (box[0] + box[1]) / 2.0 * dw
    y = (box[2] + box[3]) / 2.0 * dh
    w = (box[1] - box[0]) * dw
    h = (box[3] - box[2]) * dh
    return x, y, w, h

def convert_xml2yolo(lut, input_folder, output_folder):
    """Converts all XML annotations in input_folder to YOLO format."""
    for fname in glob.glob(os.path.join(input_folder, "*.xml")):
        xmldoc = minidom.parse(fname)
        size = xmldoc.getElementsByTagName("size")[0]
        
        width, height = int(get_text("width", size)), int(get_text("height", size))
        fname_out = os.path.join(output_folder, os.path.basename(fname).replace(".xml", ".txt"))

        with open(fname_out, "w") as f:
            for item in xmldoc.getElementsByTagName("object"):
                class_name = get_text("name", item)
                if class_name not in lut:
                    print(f"⚠️ Warning: Unknown label '{class_name}' in {fname}. Skipping.")
                    continue

                # Bounding box extraction
                bbox = item.getElementsByTagName("bndbox")[0]
                xmin, xmax = float(get_text("xmin", bbox)), float(get_text("xmax", bbox))
                ymin, ymax = float(get_text("ymin", bbox)), float(get_text("ymax", bbox))
                
                bb = convert_coordinates((width, height), (xmin, xmax, ymin, ymax))
                f.write(f"{lut[class_name]} " + " ".join(f"{x:.6f}" for x in bb) + "\n")

        print(f"✅ Converted: {fname_out}")

# Convert XML files to YOLO format
convert_xml2yolo(lut, "/kaggle/input/helmet-detection/annotations", "/kaggle/working/labels")
# Out:
# ✅ Converted: /kaggle/working/labels/BikesHelmets338.txt
# ✅ Converted: /kaggle/working/labels/BikesHelm
txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets319.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets265.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets36.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets575.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets710.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets182.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets53.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets413.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets511.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets235.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets726.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets367.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets59.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets66.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets590.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets351.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets586.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets555.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets403.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets56.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets339.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets650.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets33.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets445.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets587.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets765.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets35.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets697.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets93.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets293.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets708.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets28.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets499.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets279.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets183.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets425.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets491.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets388.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets679.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets473.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets744.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets763.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets305.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets755.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets357.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets465.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets521.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets742.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets549.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets65.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets18.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets639.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets22.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets83.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets328.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets109.txt
# ✅ Converted: /kaggle/working/labels/BikesHelmets312.txt

# %%
# ==========================
# 📌 Step 4: Load and Train YOLO Model
# ==========================
model = YOLO("yolov8n.pt")  # Load pretrained YOLOv8 model

# Train the model
results = model.train(data=yaml_path, epochs=30)
print("✅ Training complete!")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2/6.2MB 78.3MB/s 0.1s
# Ultralytics 8.3.189 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/dataset.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1/755.1KB 16.4MB/s 0.0s
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# Model summary: 129 layers, 3,011,238 parameters, 3,011,222 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4/5.4MB 70.0MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3534.8±522.8 MB/s, size: 588.9 KB)
# train: Scanning /kaggle/working/labels... 764 images, 3 backgrounds, 15 corrupt: 100% ━━━━━━━━━━━━ 764/764 403.7it/s 1.9s
# train: /kaggle/working/images/BikesHelmets103.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     408.72      81.502      71.037      83.004]
# train: /kaggle/working/images/BikesHelmets140.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     547.68        84.5      132.16         151]
# train: /kaggle/working/images/BikesHelmets205.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      263.5          43          85          74]
# train: /kaggle/working/images/BikesHelmets279.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      194.5          56         103         100]
# train: /kaggle/working/images/BikesHelmets326.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [        157        56.5          86          97]
# train: /kaggle/working/images/BikesHelmets343.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     682.27       150.5      118.22         107]
# train: /kaggle/working/images/BikesHelmets441.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      310.5        41.5          61          63]
# train: /kaggle/working/images/BikesHelmets444.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [        299          48          78          80]
# train: /kaggle/working/images/BikesHelmets530.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     313.35          74      102.11         116]
# train: /kaggle/working/images/BikesHelmets616.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [        750       297.5          68          91]
# train: /kaggle/working/images/BikesHelmets671.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [        863         251          52          52]
# train: /kaggle/working/images/BikesHelmets706.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      379.5        82.5          61          65]
# train: /kaggle/working/images/BikesHelmets75.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [        471       290.5          82         109         761       291.5          84          97       466.5         297         109         118]
# train: /kaggle/working/images/BikesHelmets764.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [        219          91          80          82]
# train: /kaggle/working/images/BikesHelmets80.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      424.5      45.298          71      82.631]
# train: New cache created: /kaggle/working/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1047.5±673.0 MB/s, size: 523.3 KB)
# val: Scanning /kaggle/working/labels.cache... 764 images, 3 backgrounds, 15 corrupt: 100% ━━━━━━━━━━━━ 764/764 824189.4it/s 0.0s0s
# train: /kaggle/working/images/BikesHelmets103.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     408.72      81.502      71.037      83.004]
# train: /kaggle/working/images/BikesHelmets140.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     547.68        84.5      132.16         151]
# train: /kaggle/working/images/BikesHelmets205.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      263.5          43          85          74]
# train: /kaggle/working/images/BikesHelmets279.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      194.5          56         103         100]
# train: /kaggle/working/images/BikesHelmets326.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [        157        56.5          86          97]
# train: /kaggle/working/images/BikesHelmets343.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     682.27       150.5      118.22         107]
# train: /kaggle/working/images/BikesHelmets441.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      310.5        41.5          61          63]
# train: /kaggle/working/images/BikesHelmets444.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [        299          48          78          80]
# train: /kaggle/working/images/BikesHelmets530.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     313.35          74      102.11         116]
# train: /kaggle/working/images/BikesHelmets616.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [        750       297.5          68          91]
# train: /kaggle/working/images/BikesHelmets671.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [        863         251          52          52]
# train: /kaggle/working/images/BikesHelmets706.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      379.5        82.5          61          65]
# train: /kaggle/working/images/BikesHelmets75.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [        471       290.5          82         109         761       291.5          84          97       466.5         297         109         118]
# train: /kaggle/working/images/BikesHelmets764.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [        219          91          80          82]
# train: /kaggle/working/images/BikesHelmets80.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      424.5      45.298          71      82.631]
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to runs/detect/train
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      2.16G      1.494      2.775      1.267         36        640: 100% ━━━━━━━━━━━━ 47/47 4.1it/s 11.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 3.2it/s 7.5s
#                    all        749       1411    0.00533      0.865      0.099     0.0604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30       2.4G      1.417      1.746      1.202         53        640: 100% ━━━━━━━━━━━━ 47/47 4.8it/s 9.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 4.0it/s 6.0s
#                    all        749       1411      0.913       0.18      0.553       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30       2.4G      1.405      1.571      1.187         61        640: 100% ━━━━━━━━━━━━ 47/47 4.9it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 4.0it/s 6.0s
#                    all        749       1411      0.655      0.664      0.651      0.387
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30       2.4G      1.409      1.455      1.186         32        640: 100% ━━━━━━━━━━━━ 47/47 5.0it/s 9.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 4.2it/s 5.8s
#                    all        749       1411      0.709      0.732      0.744      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30       2.4G      1.355      1.311      1.161         39        640: 100% ━━━━━━━━━━━━ 47/47 4.9it/s 9.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 4.3it/s 5.6s
#                    all        749       1411      0.694      0.778      0.776       0.46
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30       2.4G      1.358      1.244       1.16         50        640: 100% ━━━━━━━━━━━━ 47/47 4.9it/s 9.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 4.7it/s 5.1s
#                    all        749       1411      0.759      0.728      0.774      0.473
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30       2.4G      1.346      1.169      1.157         39        640: 100% ━━━━━━━━━━━━ 47/47 4.9it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 4.6it/s 5.2s
#                    all        749       1411      0.717      0.816        0.8      0.494
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30       2.4G      1.342      1.112      1.146         61        640: 100% ━━━━━━━━━━━━ 47/47 5.0it/s 9.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 4.7it/s 5.1s
#                    all        749       1411      0.754      0.751      0.794      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30       2.4G      1.321      1.069      1.142         48        640: 100% ━━━━━━━━━━━━ 47/47 4.9it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 4.6it/s 5.2s
#                    all        749       1411      0.747      0.782      0.786      0.495
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30       2.4G      1.323      1.013      1.134         44        640: 100% ━━━━━━━━━━━━ 47/47 4.9it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 4.7it/s 5.1s
#                    all        749       1411      0.718      0.775      0.789      0.497
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30       2.4G      1.324      0.985       1.14         47        640: 100% ━━━━━━━━━━━━ 47/47 5.0it/s 9.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 4.6it/s 5.3s
#                    all        749       1411      0.781      0.841       0.87      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30       2.4G      1.281      0.941      1.122         46        640: 100% ━━━━━━━━━━━━ 47/47 4.9it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 4.7it/s 5.1s
#                    all        749       1411      0.795      0.856      0.867      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30       2.4G       1.27     0.9394       1.12         49        640: 100% ━━━━━━━━━━━━ 47/47 4.9it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 4.3it/s 5.5s
#                    all        749       1411      0.806      0.822      0.859      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/30       2.4G      1.274     0.9425       1.13         38        640: 100% ━━━━━━━━━━━━ 47/47 4.9it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 4.6it/s 5.2s
#                    all        749       1411      0.815      0.851      0.893       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/30       2.4G      1.253     0.8727      1.112         60        640: 100% ━━━━━━━━━━━━ 47/47 4.9it/s 9.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 4.7it/s 5.1s
#                    all        749       1411      0.802      0.865      0.902      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size

# %%
# ==========================
# 📌 Step 5: Run Inference on Test Images
# ==========================
test_images = glob.glob("/kaggle/input/helmet-detection/images/*.png")

for img_path in test_images[:3]:  # Limit to 3 images for quick testing
    results = model(img_path)
    for result in results:
        result.show()  # Display image
        result.save(filename=f"result_{os.path.basename(img_path)}")
    print(f"✅ Processed {img_path}")

# %%
# ==========================
# 📌 Step 6: Export Model to ONNX
# ==========================
if model.export(format="onnx"):
    print("✅ Model exported to ONNX format successfully!")
